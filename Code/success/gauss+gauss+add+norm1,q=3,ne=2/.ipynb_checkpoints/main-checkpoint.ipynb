# %% [markdown]
# # Import packages

# %% [markdown]
# ### Import python packages

# %%
import re,os
os.environ["CUDA_VISIBLE_DEVICES"]="7"
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from IPython.display import clear_output
import pandas as pd
import math
import random
from datetime import datetime
from scipy.stats import linregress
from sklearn.decomposition import PCA
from tqdm import trange, tqdm
from mpl_toolkits.mplot3d import Axes3D
import plotly.express as px
import plotly.graph_objects as go
from sklearn.manifold import TSNE
tfk = tf.keras
tfkl = tf.keras.layers
clear_output()

# %% [markdown]
# ### Import custom packages

# %%
from MRA_generate import MRA_generate
from symae_model import SymAE, SymAE_Dense
from parameters import *
from redatuming import redatuming
from latent import latent
from plot_training import plot_training
from plot_redatuming import plot_redatuming
from plot_save import plot_save
# Out:
# Num GPUs Available:  1
# TensorFlow Version:  2.9.1

# %% [markdown]
# # Generate dataset X

# %% [markdown]
# ### Define $n_\varepsilon$ states

# %% [markdown]
# g(n,x) satisfies $n=0,1...,n_\varepsilon$, $x \in [0,1)$
# g(n,$\cdot$) is the n-th state.
# state = real object without

# %%
def g(n,x):
    if n==0:
        return math.e**(-5*(x-0.5)**2)
    elif n==1:
        return math.e**(-10*(x-0.5)**2)
fig, axs = plt.subplots(1, ne, sharex=True, sharey=True, figsize=(ne*4, 4))
for i in range(ne):
    axs[i].plot(range(d), [g(i,x/d) for x in range(d)])
plt.suptitle('Show the shape of all $n_\epsilon$ = %d states'%ne)
# Out:
# Text(0.5, 0.98, 'Show the shape of all $n_\\epsilon$ = 2 states')

# %% [markdown]
# ### Generate the dataset

# %% [markdown]
# If replace==0, without replacement everywhere. Must $n_x*n_t <= n_\varepsilon*d$ and $n_t <= d$.
# If replace==1, X[i,:] have different nuisances, but each block in D can appear multiple times in X.
# If replace==2, with replacement everywhere.
# The default is replace=1.

# %%
MRA_training = MRA_generate(d,nt,N,sigma,ne,g,replace=0)
MRA_training.generate_default()
X = MRA_training.X

# %% [markdown]
# ### Print the structure of dataset X

# %% [markdown]
# Plot how many times each block in D appears in X

# %%
print("Numbers of each state in X:")
print(pd.DataFrame(MRA_training.states).value_counts())
select_times = MRA_training.select_times
plt.figure(figsize=(5,5),dpi=100)
plt.matshow(select_times.T, aspect='auto', fignum=1)
plt.colorbar()
plt.title('How many times has each block in D been selected by X?')
plt.show()
# Out:
# Numbers of each state in X:
# 0    50
# 1    50
# dtype: int64

# %% [markdown]
# # Train SymAE

# %% [markdown]
# ### Initialize SymAE and load weights

# %%
model = SymAE(N,nt,d,p,q,kernel_size,filters,dropout_rate)
model.load_weights('./checkpoint/p=3,q=3,ne=2')
clear_output()

# %%
dropout_rate, q
# Out:
# (0.5, 3)

# %%
model.latentcat.drop.rate = 0.
model.latentcat.drop.stddev = 0.05

# %% [markdown]
# ### Select the optimizer

# %%
Adam = tf.keras.optimizers.Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999,epsilon=1e-08)
SGD = tf.keras.optimizers.SGD(learning_rate=0.001,momentum=0.0,nesterov=False)
model.compile(loss='mse',optimizer=Adam)

# %% [markdown]
# ### Train the NeuralNet

# %% [markdown]
# M: how many epochs you use

# %%
M = 1000 # How many epochs
epochs = range(M)
losses = [np.nan]*M
MRA_pca = MRA_generate(d,nt,1000,sigma,ne,g,replace=0)
pca_cb = PCA(n_components=3)
MRA_pca.generate_default()
X = MRA_training.X
clear_output()
N_shifts = MRA_pca.shifts.reshape(-1,1)
N_states = np.repeat(MRA_pca.states,nt)
df_states = pd.DataFrame(N_states,columns=['state']).astype('object') 
df_shifts = pd.DataFrame(N_shifts,columns=['shift'])
class CustomCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        losses[epoch] = logs["loss"]
        print("For epoch {:d}, loss is {:f}.".format(epoch, logs["loss"]))
        if epoch % 200 == 0:
            clear_output(wait = True)
            _, Ns = latent(model,MRA_pca)
            N_reshaped = Ns.reshape(-1,q)
            pca_N = pca_cb.fit_transform(N_reshaped)
            df = pd.DataFrame(pca_N, columns = ['1st','2nd','3rd'][0:3])
            df = pd.concat([df,df_states,df_shifts],axis=1)
            #fig = px.scatter(df, x='1st', y='2nd', color='state', text='shift', title='q=%d,loss=%f'%(q,logs["loss"]))
            fig = px.scatter_3d(df, x='1st', y='2nd', z='3rd', color='state', text='shift', title='q=%d,loss=%f'%(q,logs["loss"]))
            fig.update_layout(height=500)
            fig.show()
history = model.fit(X,X,epochs=M,verbose=0,callbacks=[CustomCallback()])
# Out:
# <div>                            <div id="e220ae29-3808-468b-b3ed-1e59bcf377d0" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
# For epoch 819, loss is 0.000238.
# For epoch 820, loss is 0.000295.
# For epoch 821, loss is 0.000276.
# For epoch 822, loss is 0.000313.
# For epoch 823, loss is 0.000277.
# For epoch 824, loss is 0.000238.
# For epoch 825, loss is 0.000241.
# For epoch 826, loss is 0.000212.
# For epoch 827, loss is 0.000192.
# For epoch 828, loss is 0.000207.
# For epoch 829, loss is 0.000203.
# For epoch 830, loss is 0.000188.
# For epoch 831, loss is 0.000193.
# For epoch 832, loss is 0.000230.
# For epoch 833, loss is 0.000222.
# For epoch 834, loss is 0.000226.
# For epoch 835, loss is 0.000222.
# For epoch 836, loss is 0.000185.
# For epoch 837, loss is 0.000206.
# For epoch 838, loss is 0.000209.
# For epoch 839, loss is 0.000192.
# For epoch 840, loss is 0.000206.
# For epoch 841, loss is 0.000200.
# For epoch 842, loss is 0.000217.
# For epoch 843, loss is 0.000231.
# For epoch 844, loss is 0.000216.
# For epoch 845, loss is 0.000212.
# For epoch 846, loss is 0.000223.
# For epoch 847, loss is 0.000215.
# For epoch 848, loss is 0.000212.
# For epoch 849, loss is 0.000232.
# For epoch 850, loss is 0.000241.
# For epoch 851, loss is 0.000212.
# For epoch 852, loss is 0.000219.
# For epoch 853, loss is 0.000256.
# For epoch 854, loss is 0.000242.
# For epoch 855, loss is 0.000221.
# For epoch 856, loss is 0.000192.
# For epoch 857, loss is 0.000233.
# For epoch 858, loss is 0.000236.
# For epoch 859, loss is 0.000268.
# For epoch 860, loss is 0.000226.
# For epoch 861, loss is 0.000223.
# For epoch 862, loss is 0.000199.
# For epoch 863, loss is 0.000269.
# For epoch 864, loss is 0.000277.
# For epoch 865, loss is 0.000234.
# For epoch 866, loss is 0.000243.
# For epoch 867, loss is 0.000246.
# For epoch 868, loss is 0.000299.
# For epoch 869, loss is 0.000263.
# For epoch 870, loss is 0.000231.
# For epoch 871, loss is 0.000219.
# For epoch 872, loss is 0.000235.
# For epoch 873, loss is 0.000220.
# For epoch 874, loss is 0.000320.
# For epoch 875, loss is 0.000276.
# For epoch 876, loss is 0.000260.
# For epoch 877, loss is 0.000264.
# For epoch 878, loss is 0.000275.
# For epoch 879, loss is 0.000319.
# For epoch 880, loss is 0.000277.
# For epoch 881, loss is 0.000252.
# For epoch 882, loss is 0.000268.
# For epoch 883, loss is 0.000282.
# For epoch 884, loss is 0.000598.
# For epoch 885, loss is 0.000499.
# For epoch 886, loss is 0.000328.
# For epoch 887, loss is 0.000281.
# For epoch 888, loss is 0.000283.
# For epoch 889, loss is 0.000258.
# For epoch 890, loss is 0.000247.
# For epoch 891, loss is 0.000211.
# For epoch 892, loss is 0.000326.
# For epoch 893, loss is 0.000338.
# For epoch 894, loss is 0.000240.
# For epoch 895, loss is 0.000222.
# For epoch 896, loss is 0.000201.
# For epoch 897, loss is 0.000224.
# For epoch 898, loss is 0.000243.
# For epoch 899, loss is 0.000211.
# For epoch 900, loss is 0.000208.
# For epoch 901, loss is 0.000223.
# For epoch 902, loss is 0.000200.
# For epoch 903, loss is 0.000198.
# For epoch 904, loss is 0.000224.
# For epoch 905, loss is 0.000211.
# For epoch 906, loss is 0.000222.
# For epoch 907, loss is 0.000203.
# For epoch 908, loss is 0.000219.
# For epoch 909, loss is 0.000224.
# For epoch 910, loss is 0.000201.
# For epoch 911, loss is 0.000180.
# For epoch 912, loss is 0.000208.
# For epoch 913, loss is 0.000289.
# For epoch 914, loss is 0.000246.
# For epoch 915, loss is 0.000256.
# For epoch 916, loss is 0.000234.
# For epoch 917, loss is 0.000215.
# For epoch 918, loss is 0.000232.
# For epoch 919, loss is 0.000187.
# For epoch 920, loss is 0.000207.
# For epoch 921, loss is 0.000206.
# For epoch 922, loss is 0.000198.
# For epoch 923, loss is 0.000200.
# For epoch 924, loss is 0.000196.
# For epoch 925, loss is 0.000247.
# For epoch 926, loss is 0.000208.
# For epoch 927, loss is 0.000226.
# For epoch 928, loss is 0.000226.
# For epoch 929, loss is 0.000201.
# For epoch 930, loss is 0.000209.
# For epoch 931, loss is 0.000216.
# For epoch 932, loss is 0.000211.
# For epoch 933, loss is 0.000235.
# For epoch 934, loss is 0.000209.
# For epoch 935, loss is 0.000239.
# For epoch 936, loss is 0.000280.
# For epoch 937, loss is 0.000262.
# For epoch 938, loss is 0.000248.
# For epoch 939, loss is 0.000225.
# For epoch 940, loss is 0.000263.
# For epoch 941, loss is 0.000188.
# For epoch 942, loss is 0.000227.
# For epoch 943, loss is 0.000208.
# For epoch 944, loss is 0.000202.
# For epoch 945, loss is 0.000233.
# For epoch 946, loss is 0.000224.
# For epoch 947, loss is 0.000197.
# For epoch 948, loss is 0.000193.
# For epoch 949, loss is 0.000213.
# For epoch 950, loss is 0.000206.
# For epoch 951, loss is 0.000195.
# For epoch 952, loss is 0.000205.
# For epoch 953, loss is 0.000208.
# For epoch 954, loss is 0.000201.
# For epoch 955, loss is 0.000235.
# For epoch 956, loss is 0.000225.
# For epoch 957, loss is 0.000213.
# For epoch 958, loss is 0.000209.
# For epoch 959, loss is 0.000213.
# For epoch 960, loss is 0.000244.
# For epoch 961, loss is 0.000243.
# For epoch 962, loss is 0.000282.
# For epoch 963, loss is 0.000269.
# For epoch 964, loss is 0.000252.
# For epoch 965, loss is 0.000286.
# For epoch 966, loss is 0.000289.
# For epoch 967, loss is 0.000427.
# For epoch 968, loss is 0.000442.
# For epoch 969, loss is 0.000350.
# For epoch 970, loss is 0.000386.
# For epoch 971, loss is 0.000222.
# For epoch 972, loss is 0.000206.
# For epoch 973, loss is 0.000186.
# For epoch 974, loss is 0.000186.
# For epoch 975, loss is 0.000191.
# For epoch 976, loss is 0.000175.
# For epoch 977, loss is 0.000197.
# For epoch 978, loss is 0.000198.
# For epoch 979, loss is 0.000196.
# For epoch 980, loss is 0.000193.
# For epoch 981, loss is 0.000178.
# For epoch 982, loss is 0.000183.
# For epoch 983, loss is 0.000185.
# For epoch 984, loss is 0.000187.
# For epoch 985, loss is 0.000179.
# For epoch 986, loss is 0.000171.
# For epoch 987, loss is 0.000195.
# For epoch 988, loss is 0.000201.
# For epoch 989, loss is 0.000197.
# For epoch 990, loss is 0.000177.
# For epoch 991, loss is 0.000231.
# For epoch 992, loss is 0.000305.
# For epoch 993, loss is 0.000227.
# For epoch 994, loss is 0.000184.
# For epoch 995, loss is 0.000187.
# For epoch 996, loss is 0.000200.
# For epoch 997, loss is 0.000210.
# For epoch 998, loss is 0.000214.
# For epoch 999, loss is 0.000230.

# %% [markdown]
# ### Plot loss-epoch graph

# %%
plt.plot(epochs,losses)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %% [markdown]
# ### Save weights

# %%
model.save_weights('./checkpoint/'+'p=%d,q=%d,ne=2'%(p,q))
print("weights saved")
# Out:
# weights saved

# %% [markdown]
# ### Visualize the training result

# %% [markdown]
# find_state(state): Generate a data set, whose shape is $(1,n_\tau,d)$, and its state equal to the input of this function

# %%
def find(state,nuisance):
    '''
    Generate a dataset with N=1 and this specific state

    Parameters
    ----------
    state : int
        The state you want
        
    Returns
    ----------
    MRA_data : class MRA_generate
    '''
    MRA_data = MRA_generate(d,nt,1,sigma,ne,g,replace=1)
    for i in range(1000):
        MRA_data.generate_default()
        if MRA_data.states[0] != state:
            continue
        for j in range(nt):
            if MRA_data.shifts[0][j] == nuisance:
                return MRA_data, j
test_X = find(0,0)[0].X
fig = plot_training(model,test_X)
# Out:
# 1/1 [==============================] - 1s 654ms/step

# %% [markdown]
# ### Save plot

# %%
plot_save(fig,ID=-1)

# %% [markdown]
# # Redatuming

# %% [markdown]
# ### Choose which 2 states and shifts you want to redatum

# %%
MRA1, t1 = find(0,0)
MRA2, t2 = find(1,36)

# %% [markdown]
# ### Redatuming and the visualize it

# %%
redatum = redatuming(model,MRA1,MRA2,t1,t2)
MSE_C1_N2, MSE_C2_N1 = redatum.MSE()
fig = plot_redatuming(redatum)
clear_output()
print('The MSE of C1N2 is: %f'%MSE_C1_N2)
print('The MSE of C2N1 is:%f'%MSE_C2_N1)
# Out:
# The MSE of C1N2 is: 0.103901
# The MSE of C2N1 is:0.171304

# %% [markdown]
# ### Save redatuming plot

# %%
plot_save(fig,ID=-1)

# %% [markdown]
# ### List many redatuming

# %%
def dec(latent_code):
    tem = latent_code[np.newaxis, np.newaxis, :]
    tem = np.repeat(tem, nt, axis=1)
    tem = model.mixer.predict(tem, verbose=0)
    return tem[0,0,:]
def enc(state, shift):
    tem = np.array( [g(state, ((k+shift)%d)/d) for k in range(d)] )
    tem = tem[np.newaxis, np.newaxis, :, np.newaxis]
    tem = np.repeat(tem, nt, axis=1)
    tem = model.encoder.predict(tem, verbose=0)
    return tem[0][0:p+q]

# %%
state_source = 0
nuisance_source = 1
fig, axs = plt.subplots(1, d, sharex=True, sharey=True, figsize=(4*d,4), dpi=40)
for i in trange(d):
    coherent_code = enc(state_source, 0)[0: p]
    nuisance_code = enc(nuisance_source, i)[p: p+q]
    latent_code = np.concatenate([coherent_code, nuisance_code], axis=0)
    axs[i].plot(range(d), dec(latent_code))
    axs[i].set_title('%d'%i)
plt.suptitle('$\hat{X}_{s=%d \mapsto s=%d}$'%(nuisance_source, state_source), fontsize=50)
plt.subplots_adjust(top=0.6)
plt.show()
#fig.savefig('./plots/%dto%d'%(nuisance_source, state_source))
# Out:
# 100%|█████████████████████████████████████████| 100/100 [00:19<00:00,  5.03it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [18], in <cell line: 13>()
#      11 plt.subplots_adjust(top=0.6)
#      12 plt.show()
# ---> 13 fig.savefig('./plots/%dto%d'%(nuisance_source, state_source))
#
# File ~/software/anaconda/envs/MRA/lib/python3.9/site-packages/matplotlib/figure.py:3019, in Figure.savefig(self, fname, transparent, **kwargs)
#    3015     for ax in self.axes:
#    3016         stack.enter_context(
#    3017             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3019 self.canvas.print_figure(fname, **kwargs)
#
# File ~/software/anaconda/envs/MRA/lib/python3.9/site-packages/matplotlib/backend_bases.py:2319, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2315 try:
#    2316     # _get_renderer may change the figure dpi (as vector formats
#    2317     # force the figure dpi to 72), so we need to set it again here.
#    2318     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319         result = print_method(
#    2320             filename,
#    2321             facecolor=facecolor,
#    2322             edgecolor=edgecolor,
#    2323             orientation=orientation,
#    2324             bbox_inches_restore=_bbox_inches_restore,
#    2325             **kwargs)
#    2326 finally:
#    2327     if bbox_inches and restore_bbox:
#
# File ~/software/anaconda/envs/MRA/lib/python3.9/site-packages/matplotlib/backend_bases.py:1648, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1640     _api.warn_deprecated(
#    1641         '3.3', name=name, removal='3.6',
#    1642         message='%(name)s() got unexpected keyword argument "'
#    1643                 + arg + '" which is no longer supported as of '
#    1644                 '%(since)s and will become an error '
#    1645                 '%(removal)s')
#    1646     kwargs.pop(arg)
# -> 1648 return func(*args, **kwargs)
#
# File ~/software/anaconda/envs/MRA/lib/python3.9/site-packages/matplotlib/_api/deprecation.py:412, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     402     deprecation_addendum = (
#     403         f"If any parameter follows {name!r}, they should be passed as "
#     404         f"keyword, not positionally.")
#     405     warn_deprecated(
#     406         since,
#     407         name=repr(name),
#    (...)
#     410                  else deprecation_addendum,
#     411         **kwargs)
# --> 412 return func(*inner_args, **inner_kwargs)
#
# File ~/software/anaconda/envs/MRA/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:541, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     494 """
#     495 Write the figure to a PNG file.
#     496
#    (...)
#     538     *metadata*, including the default 'Software' key.
#     539 """
#     540 FigureCanvasAgg.draw(self)
# --> 541 mpl.image.imsave(
#     542     filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     543     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/software/anaconda/envs/MRA/lib/python3.9/site-packages/matplotlib/image.py:1675, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1673 pil_kwargs.setdefault("format", format)
#    1674 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1675 image.save(fname, **pil_kwargs)
#
# File ~/software/anaconda/envs/MRA/lib/python3.9/site-packages/PIL/Image.py:2209, in Image.save(self, fp, format, **params)
#    2207         fp = builtins.open(filename, "r+b")
#    2208     else:
# -> 2209         fp = builtins.open(filename, "w+b")
#    2211 try:
#    2212     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: './plots/1to0.png'

# %% [markdown]
# # 3d-PCA of latent space

# %% [markdown]
# Repeat the same thing as 2d-PCA did, but the target dimension of PCA is switched to 3.

# %% [markdown]
# ### Initialize MRA and PCA

# %%
pca = PCA(n_components=3)
MRA_pca = MRA_generate(d,nt,1000,sigma,ne,g,replace=1)
MRA_pca.generate_default()
Cs,Ns = latent(model,MRA_pca)

# %% [markdown]
# ### PCA of p-space

# %%
pca.fit(Cs)
pca_C = pca.fit_transform(Cs)
df = pd.DataFrame(pca_C, columns = ['1st','2nd','3rd'])
tem = pd.DataFrame(MRA_pca.states,columns=['state']).astype('object')
df = pd.concat([df,tem],axis=1)
fig = px.scatter_3d(df, x='1st', y='2nd', z='3rd', color='state')
fig.show()

# %% [markdown]
# ### PCA of q-space of one specific state

# %%
state = 0
N_reshaped = Ns[MRA_pca.states==state,:].reshape(-1,q) 
N_shifts = MRA_pca.shifts[MRA_pca.states==state,:].reshape(-1,1)
pca = PCA(n_components=3)
pca.fit(N_reshaped)
pca_N = pca.fit_transform(N_reshaped)
df = pd.DataFrame(pca_N, columns = ['1st','2nd','3rd'])
tem = pd.DataFrame(N_shifts,columns=['shift'])
df = pd.concat([df,tem],axis=1)
fig = px.scatter_3d(df, x='1st', y='2nd', z='3rd', color='shift')
fig.show()

# %% [markdown]
# ### PCA in q-space of all states

# %%
N_reshaped = Ns.reshape(-1,q)
N_shifts = MRA_pca.shifts.reshape(-1,1)
pca.fit(N_reshaped)
pca_N = pca.fit_transform(N_reshaped)
df = pd.DataFrame(pca_N, columns = ['1st','2nd','3rd'])
df_states = pd.DataFrame(np.repeat(MRA_pca.states,nt),columns=['state']).astype('object')
df_shifts = pd.DataFrame(N_shifts,columns=['shift'])
df = pd.concat([df,df_states,df_shifts],axis=1)
fig = px.scatter_3d(df, x='1st', y='2nd', z='3rd', color='state')
fig.show()

# %% [markdown]
# # 2d-PCA of latent space

# %% [markdown]
# ### Initialize PCA data

# %%
MRA_pca = MRA_generate(d,nt,1000,sigma,ne,g,replace=1)
MRA_pca.generate_default()
Cs, Ns = latent(model,MRA_pca)
pca = PCA(n_components=2)

# %% [markdown]
# ### Plot PCA of p-space

# %% [markdown]
# p-space is another name of the latent coherent space

# %%
pca_C = pca.fit_transform(Cs)
center = np.empty((ne,2))
fig = plt.figure(figsize=(5,4),dpi=100)
for i in range(ne):
    center[i,:] = sum(pca_C[MRA_pca.states==i,:])/sum(MRA_pca.states==i)
    plt.text(center[i,0],center[i,1],"state=%d"%i,fontsize=15)
for i in trange(1000):
    plt.scatter(pca_C[i,0],pca_C[i,1],color='C%d'%(MRA_pca.states[i]))
plt.title('PCA of p-space',fontsize=15)
plt.tick_params(labelsize=15)
plt.tight_layout()

# %% [markdown]
# ### Plot PCA of q-space, only use one state

# %% [markdown]
# q-space is another name of latent nuisance space

# %% [markdown]
# In the plot below we see a "torus" or a "ring", which makes a lot of sense, because the nuisance code $\mathbb{Z}_d$ behaves like a "loop".

# %%
state = 2
N_reshaped = Ns[MRA_pca.states==state,:].reshape(-1,q)
N_shifts = MRA_pca.shifts[MRA_pca.states==state,:]
pca.fit(N_reshaped)
pca_N = pca.fit_transform(N_reshaped)
fig = plt.figure(figsize=(16,12),dpi=100)
for i in trange(1000):
    plt.scatter(pca_N[i,0],pca_N[i,1],color='C0')
    plt.text(pca_N[i,0],pca_N[i,1],"shift=%d"%N_shifts[i//nt,i%nt],fontsize=15)
plt.title('PCA of q-space of state %d'%state,fontsize=25)
plt.tick_params(labelsize=25)

# %% [markdown]
# ### PCA of q-space uisng all states

# %% [markdown]
# In SymAE, we hope the latent nuisance code only depends on the nuisance part of the data, but has no relationship with which state it is.
# In the plot, different colors denote latent nuisance code from different states.
# So ideally, we hope all the 4 "ring" (of 4 different colors) shown in the plot are perfectly overlapped with each other.
# But that's not what is shown in the plot below. This indicates that redauming won't be successful.

# %%
N_reshaped = Ns.reshape(-1,q)
pca = PCA(n_components=2)
pca.fit(N_reshaped)
pca_N = pca.transform(N_reshaped)
fig = plt.figure(figsize=(16,12),dpi=100)
for i in trange(2000):
    plt.scatter(pca_N[i,0],pca_N[i,1],color='C%d'%(MRA_pca.states[i//nt]))
    plt.text(pca_N[i,0],pca_N[i,1],"%d"%MRA_pca.shifts[i//nt,i%nt],fontsize=15,fontweight='ultralight')
plt.title('PCA of q-space of all states',fontsize=25)
plt.tick_params(labelsize=25)
blue_patch = mpatches.Patch(color='C0', label='state=0')
orange_patch = mpatches.Patch(color='C1', label='state=1')
green_patch = mpatches.Patch(color='C2', label='state=2')
red_patch = mpatches.Patch(color='C3', label='state=3')
plt.legend(handles=[blue_patch,orange_patch,green_patch,red_patch])
#plt.tight_layout()
#plt.xlim(-5,5)
#plt.ylim(-5,5)
plt.show()
