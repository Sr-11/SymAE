# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="5"
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from IPython.display import clear_output
import pandas as pd
import math
from sklearn.decomposition import PCA
import plotly.express as px
from tqdm import trange
from MRA_generate import MRA_generate
from symae_model import SymAE
from parameters import *
from latent import latent
from redatuming import redatuming
from plot_redatuming import plot_redatuming
def g(n,x):
    if n==0:
        return math.e**(-5*(x-0.5)**2)
    elif n==1:
        return math.e**(-10*(x-0.5)**2)
    elif n==2:
        if x<0.3:
            return 3*x
        elif x<0.6:
            return 3*(0.6-x)
        else:
            return 0
    elif n==3:
        return int(x<0.5)
    elif n==4:
        return math.e**(-30*(x-0.5)**2)
    elif n==5:
        return math.cos(2*math.pi*x)
    elif n==6:
        return math.e**(-9*x**2)
    else:
        return np.inf
def g(n,x):
    return math.e**(-n/4*(x-0.5)**2)
def g(n,x):
    if n==1:
        return int(x<0.5)
    elif n==2:
        return math.e**(-9*(x)**2)
    elif n==0:
        return math.cos(2*math.pi*x)
fig, axs = plt.subplots(1, ne, sharex=True, sharey=True)
for i in range(ne):
    axs[i].plot(range(d), [g(i,x/d) for x in range(d)])
plt.suptitle('Show the shape of all $n_\epsilon$ = %d states'%ne)
MRA_training = MRA_generate(d,nt,N,sigma,ne,g,replace=1)
pca_cb = PCA(n_components=2)
MRA_pca = MRA_generate(d,nt,1000,sigma,ne,g,replace=1)
MRA_training.generate_default()
MRA_pca.generate_default()
X = MRA_training.X
clear_output()
N_shifts = MRA_pca.shifts.reshape(-1,1)
N_states = np.repeat(MRA_pca.states,nt)
img_list=[]
clear_output()
fig.show()

# %%
class CustomCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        print("For epoch {:d}, loss is {:f}.".format(epoch, logs["loss"]))
        if epoch % 50 == 0:
            clear_output(wait = True)
            _,Ns = latent(model,MRA_pca)
            N_reshaped = Ns.reshape(-1,q)
            pca_N = pca_cb.fit_transform(N_reshaped)
            #pca_N = N_reshaped[:,2:4]
            df = pd.DataFrame(pca_N, columns = ['1st','2nd'])
            df_states = pd.DataFrame(N_states,columns=['state']).astype('object') 
            df_shifts = pd.DataFrame(N_shifts,columns=['shift'])
            df = pd.concat([df,df_states,df_shifts],axis=1)
            fig = px.scatter(df, x='1st', y='2nd', color='state', text='shift', title='q=%d,loss=%f'%(q,logs["loss"]))
            fig.update_layout(height=500, margin=dict(l=0, r=0, t=60, b=0))
            img_list.append(fig)
            fig.show()
            #model.save_weights('./checkpoint/'+'p=30,q=20,dropout')

# %%
model = SymAE(N,nt,d,p,q,kernel_size,filters,dropout_rate)
#model.load_weights('./checkpoint/'+'p=3,q=3')
#model.load_weights('./checkpoint/'+'p=3,q=10,ber,ne=3')
#model.load_weights('./checkpoint/'+'p=3,q=15,add,nor=1')
model.load_weights('./checkpoint/'+'p=30,q=20,dropout')
clear_output()

# %%
model.latentcat.drop.stddev = 1
model.latentcat.drop.rate = 0.5

# %%
Adam = tf.keras.optimizers.Adam(learning_rate=0.001,beta_1=0.9,beta_2=0.999,epsilon=1e-07)
SGD = tf.keras.optimizers.SGD(learning_rate=0.001,momentum=0.0,nesterov=False)
model.compile(loss='mse',optimizer=Adam)
history = model.fit(X,X,epochs=100000,verbose=0,callbacks=[CustomCallback()])
# Out:
# For epoch 501, loss is 0.001530.
# For epoch 502, loss is 0.001376.
# For epoch 503, loss is 0.001234.
# For epoch 504, loss is 0.001398.
# For epoch 505, loss is 0.001420.
# For epoch 506, loss is 0.001462.
# For epoch 507, loss is 0.001418.
# For epoch 508, loss is 0.001509.
# For epoch 509, loss is 0.001655.
# For epoch 510, loss is 0.001564.
# For epoch 511, loss is 0.001496.
# For epoch 512, loss is 0.001380.
# For epoch 513, loss is 0.001285.
# For epoch 514, loss is 0.001510.
# For epoch 515, loss is 0.001398.
# For epoch 516, loss is 0.001600.
# For epoch 517, loss is 0.001764.
# For epoch 518, loss is 0.001675.
# For epoch 519, loss is 0.001370.
# For epoch 520, loss is 0.001460.
# For epoch 521, loss is 0.001356.
# For epoch 522, loss is 0.001682.
# For epoch 523, loss is 0.001283.
# For epoch 524, loss is 0.002688.
# For epoch 525, loss is 0.002768.
# For epoch 526, loss is 0.001661.
# For epoch 527, loss is 0.001816.
# For epoch 528, loss is 0.001521.
# For epoch 529, loss is 0.001383.
# For epoch 530, loss is 0.001384.
# For epoch 531, loss is 0.001242.
# For epoch 532, loss is 0.001259.
# For epoch 533, loss is 0.001377.
# For epoch 534, loss is 0.001392.
# For epoch 535, loss is 0.001363.
# For epoch 536, loss is 0.001497.
# For epoch 537, loss is 0.001319.
# For epoch 538, loss is 0.001305.
# For epoch 539, loss is 0.001315.
# For epoch 540, loss is 0.001503.
# For epoch 541, loss is 0.001337.
# For epoch 542, loss is 0.001271.
# For epoch 543, loss is 0.001298.
# For epoch 544, loss is 0.001476.
# For epoch 545, loss is 0.001449.
# For epoch 546, loss is 0.001212.
# For epoch 547, loss is 0.001278.
# For epoch 548, loss is 0.001160.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 4>()
#       2 SGD = tf.keras.optimizers.SGD(learning_rate=0.001,momentum=0.0,nesterov=False)
#       3 model.compile(loss='mse',optimizer=Adam)
# ----> 4 history = model.fit(X,X,epochs=100000,verbose=0,callbacks=[CustomCallback()])
#
# File ~/software/anaconda/envs/MRA/lib/python3.9/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/software/anaconda/envs/MRA/lib/python3.9/site-packages/keras/engine/training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File ~/software/anaconda/envs/MRA/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/software/anaconda/envs/MRA/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/software/anaconda/envs/MRA/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~/software/anaconda/envs/MRA/lib/python3.9/site-packages/tensorflow/python/eager/function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/software/anaconda/envs/MRA/lib/python3.9/site-packages/tensorflow/python/eager/function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/software/anaconda/envs/MRA/lib/python3.9/site-packages/tensorflow/python/eager/function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File ~/software/anaconda/envs/MRA/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
model.save_weights('./checkpoint/'+'p=30,q=20,dropout')

# %%
def find(state,nuisance):
    MRA_data = MRA_generate(d,nt,1,sigma,ne,g,replace=2)
    for i in range(100):
        MRA_data.generate_default()
        if MRA_data.states[0] != state:
            continue
        for j in range(nt):
            if MRA_data.shifts[0][j] == nuisance:
                return MRA_data, j
MRA1, t1 = find(0,40)
MRA2, t2 = find(2,40)
redatum = redatuming(model,MRA1,MRA2,t1,t2)
clear_output()
fig = plot_redatuming(redatum)

# %%
def dec(latent_code):
    tem = latent_code[np.newaxis, np.newaxis, :]
    tem = np.repeat(tem, nt, axis=1)
    tem = model.mixer.predict(tem, verbose=0)
    return tem[0,0,:,0]
def enc(state, shift):
    tem = np.array( [g(state, ((k+shift)%d)/d) for k in range(d)] )
    tem = tem[np.newaxis, np.newaxis, :]
    tem = np.repeat(tem, nt, axis=1)
    #for i in range(nt):
    #    tem[0,i,:] = np.array( [g(state, ((k+shift+i*5)%d)/d) for k in range(d)] )
    tem = model.encoder.predict(tem, verbose=0)
    MRA, t = find(state, shift)
    ppp= model.encoder.predict(MRA.X, verbose=0)[0][0:p]
    qqq= model.encoder.predict(MRA.X, verbose=0)[0][p+t*q:p+t*q+q]
    return np.concatenate([ppp,qqq],axis=0)
    return tem[0][0:p+q]

def enc_repeat(state, shift):
    tem = np.array( [g(state, ((k+shift)%d)/d) for k in range(d)] )
    tem = tem[np.newaxis, np.newaxis, :]
    tem = np.repeat(tem, nt, axis=1)
    tem = model.encoder.predict(tem, verbose=0)
    
    return tem[0][0:p+q]

state_source = 0
nuisance_source = 2
fig, axs = plt.subplots(1, d//10, sharex=True, sharey=True, figsize=(4*d//10,4), dpi=40)
for i in trange(d//10):
    coherent_code = enc(state_source, 0)[0: p]
    nuisance_code = enc(nuisance_source, i*10)[p: p+q]
    latent_code = np.concatenate([coherent_code, nuisance_code], axis=0)
    axs[i].plot(range(d), dec(latent_code))
    axs[i].set_title('shift=%d'%(i*10))
plt.suptitle('$\hat{X}_{s=%d \mapsto s=%d}$'%(nuisance_source, state_source), fontsize=50)
plt.subplots_adjust(top=0.6)
plt.show()
#fig.savefig('./plots/%dto%d'%(nuisance_source, state_source))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:06<00:00,  1.58it/s]

# %%
#画30个不要动
_,Ns = latent(model,MRA_pca)
N_reshaped = Ns.reshape(-1,q)
pca_N = N_reshaped
df = pd.DataFrame(pca_N)
df_states = pd.DataFrame(N_states,columns=['state']).astype('object') 
df_shifts = pd.DataFrame(N_shifts,columns=['shift'])
df = pd.concat([df,df_states,df_shifts],axis=1)
for qq in range(q):
    fig = px.scatter(df, x='shift', y=qq, color='state')
    fig.update_layout(height=200, width=400, margin=dict(l=0, r=0, t=0, b=0))
    fig.show()

# %%
pca_code = []
for s in range(ne):
    co_list=[]
    for i in range(d):
        co_list.append(enc_repeat(s,i)[0:p])
    coherent_code = np.array(co_list)
    pca = PCA(3)
    pca_code.append(coherent_code)
pca_N = pca.fit_transform(np.vstack(pca_code))

# %%
N_states = np.array([0]*d+[1]*d+[2]*d)

# %%
N_shifts = np.array(list(range(d))*3)

# %%
df = pd.DataFrame(pca_N)
df_states = pd.DataFrame(N_states,columns=['state']).astype('object') 
df_shifts = pd.DataFrame(N_shifts,columns=['shift'])
,2.456657886505127,2.509570837020874,2.5682532787323,2.613861083984375,2.645730495452881,2.5833892822265625,2.487792730331421,2.346595287322998,2.327761650085449,2.3874571323394775,2.4550230503082275,2.399916887283325,2.4010071754455566,2.3079018592834473,2.22184419631958,2.1175148487091064,2.0457372665405273,2.064959764480591,2.0946476459503174,2.0042221546173096,1.9185597896575928,1.742008924484253,1.5672904253005981,1.42 ...

# %%
dim = 2
pca = PCA(n_components=dim)
MRA_pca = MRA_generate(d,nt,1000,sigma,ne,g,replace=1)
MRA_pca.generate_default()
Cs,Ns = latent(model,MRA_pca)

# %%
Cs.shape
pca_C = pca.fit_transform(Cs)
pca_C.shape

# %%
enc_repeat(0,0).shape

# %%
pca.transform(enc(0,0)[np.newaxis,0:p])

# %%
df = pd.DataFrame(pca_C, columns = ['1st','2nd','3rd'][0:dim])
df_states = pd.DataFrame(MRA_pca.states,columns=['state']).astype('object')
df = pd.concat([df,df_states,df_shifts],axis=1)
#df = df[df['state']==0]
df = df[0:1000]
fig = px.scatter(df, x='1st', y='2nd', color='state')
fig.update_layout(height=600, margin=dict(l=0, r=0, t=0, b=0))
fig.show()

# %%
N_reshaped = Ns.reshape(-1,q)
N_shifts = MRA_pca.shifts.reshape(-1,1)
pca_N = pca.fit_transform(N_reshaped)
pca_N = pca.fit_transform(Cs)
pca_N = N_reshaped[:,1:3]
if dim == 3:
    pca_N = N_reshaped
    df = pd.DataFrame(pca_N, columns = ['1st','2nd','3rd'][0:dim])
    df_states = pd.DataFrame(np.repeat(MRA_pca.states,nt),columns=['state']).astype('object')
    df_shifts = pd.DataFrame(N_shifts,columns=['shift'])
    df = pd.concat([df,df_states,df_shifts],axis=1)
    fig = px.scatter_3d(df, x='1st', y='2nd', z='3rd', color='state', text='shift')
if dim ==2:
    df = pd.DataFrame(pca_N, columns = ['1st','2nd','3rd'][0:dim])
    df_states = pd.DataFrame(np.repeat(MRA_pca.states,nt),columns=['state']).astype('object')
    df_shifts = pd.DataFrame(N_shifts,columns=['shift'])
    df = pd.concat([df,df_states,df_shifts],axis=1)
    #df = df[df['state']==0]
    df = df[0:1000]
    fig = px.scatter(df, x='1st', y='2nd', color='state', text='shift')
    fig.update_layout(height=600, margin=dict(l=0, r=0, t=0, b=0))
fig.show()

# %%
def dec(latent_code):
    tem = latent_code[np.newaxis, np.newaxis, :]
    tem = np.repeat(tem, nt, axis=1)
    tem = model.mixer.predict(tem, verbose=0)
    return tem[0,0,:,0]
def enc(state, shift):
    tem = np.array( [g(state, ((k+shift)%d)/d) for k in range(d)] )
    tem = tem[np.newaxis, np.newaxis, :, np.newaxis]
    tem = np.repeat(tem, nt, axis=1)
    tem = model.encoder.predict(tem, verbose=0)
    return tem[0][0:p+q]
state_source = 0
nuisance_source = 0
fig, axs = plt.subplots(1, 1, sharex=True, sharey=True, figsize=(4,4), dpi=200)
a=40
b=0
for i in np.arange(0,11,1):
    alpha = 0.1*i
    coherent_code = enc(state_source, 0)[0: p]
    nuisance_code55 = enc(nuisance_source, a)[p: p+q]
    nuisance_code56 = enc(nuisance_source, b)[p: p+q]
    Cos = sum(nuisance_code56*nuisance_code55)
    angle55 = np.arccos(Cos)*alpha
    angle56 = np.arccos(Cos)*(1-alpha)
    nuisance_code = np.sin(angle55)*nuisance_code55 + np.sin(angle56)*nuisance_code56
    nuisance_code = nuisance_code / np.linalg.norm(nuisance_code)
    latent_code = np.concatenate([coherent_code, nuisance_code], axis=0)
    latent_code55 = np.concatenate([coherent_code, nuisance_code55], axis=0)
    latent_code56 = np.concatenate([coherent_code, nuisance_code56], axis=0)
    c=alpha*a+(1-alpha)*b
    axs.plot(range(d), dec(latent_code), color=(alpha,0,1-alpha))
    #axs.plot(range(d), [g(state_source, ((k+c)%d)/d) for k in range(d)], color=(1,0,1))
    #axs[i].plot(range(d), dec(latent_code55), label='output %d'%a)
    #axs[i].plot(range(d), dec(latent_code56), label='output %d'%b)
    #axs.legend()
plt.legend()
plt.show()
#fig.savefig('./plots/%dto%d'%(nuisance_source, state_source))

# %%
import os
import imageio
images = []
scope = PlotlyScope(
    plotlyjs="https://cdn.plot.ly/plotly-latest.min.js",
    # plotlyjs="/path/to/local/plotly.js",
)
for i in trange(len(img_list)):
    fig = img_list[i]
    with open("fig2.png", "wb") as f:
        f.write(scope.transform(fig, format="png"))
    images.append(imageio.imread('./fig2.png'))
imageio.mimsave('./movie_add.gif', images)

# %%
from kaleido.scopes.plotly import PlotlyScope
import plotly.graph_objects as go

# %%
img_list[435]

# %%
from tqdm import trange
